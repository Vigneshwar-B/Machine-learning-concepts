# %% [markdown]
# # 1/12/2022 machine learning Day-2

# %% [raw]
# 286.algorithms
#
# how algorithm learns :
#     algorithm learn a mapping from input to output
# estimate the price of oil
#    oil=demand+supply+speculation+other factors.
#     if we analyze all the factors we can predicts the price of oil ,thats machine learning.

# %% [raw]
# 287. Machine learning algorithm vs Machine learning model
# An algorithm in machine learning is a procedure that is run on data to create a machine learning model.
# machine learning algorithms performs " pattern recognition"
#
# Algorithm learn from data or are fit on a data set
# Model in machine learning is the output of machine learning algorithm run on data
# fit->learn
# algorithm->apply data-> results known as model.
# a model represents what ws learned by a machine learning algorithm.
# algorithm example: linear reg,logistic,decision tree
# model example : model.pkl

# %% [raw]
# 288.supervised vs unsupervised learning.
# supervised learning algortims:
#     1.linear regression
#     2.linear discriminant analysis
#     3.logistic regression
#     4.naive bayes classifier
#     5.multiple classifier
#     7. knn classifier
#     8.svm
#     9.decision tree
#     10.ensemble technique
# unsupervised learning:
#     1. k-mean clustering
#     2. high dimensional clustering
#     3.hierarichical clustering
#     4.pca

# %% [raw]
# 289. dependent vs independent variables
#  y=>f(x)=x^2
#
#     x-> independent ,y-> dependent.

# %% [raw]
# How To Load Machine Learning Data: Vigneshwar
#     Considerations When Loading CSV Data:
#         There are a number of considerations when loading your machine learning data from CSV files.
# For reference, you can learn a lot about the expectations for CSV files by reviewing the CSV request
# for comment titled Common Format and MIME Type for Comma-Separated Values (CSV) Files
#     File Header:
#         Does your data have a file header? If so this can help in automatically assigning names to each column of data.
# If not, you may need to name your attributes manually.Either way, you should explicitly specify whether or not your
# CSV file had a file header when loading your data.

# %% [raw]
# 291. codding

# %%
import pandas as pd
df=pd.read_csv('pima-indians-diabetes.csv')

# %%
df
# Out:
#      Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
df.head()
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
df.tail()
# Out:
#      Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0

# %% [raw]
# If no header is available it takes first row as header ,header=None .
# columns=['name of columns']

# %%
df.corr()
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# Plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# Pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# Preg   0.544341  0.221898
# Plas   0.263514  0.466581
# Pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %% [raw]
# #import data from url
# df1=pd.read_csv("https://victo.com/cmv.csv")

# %% [raw]
# to read the text file
# pd.read_table
# for excel file
# pd.read_excel
# need to import xlrd==1.20
# !pip install xlrd==1.20

# %%
#295. skipping some rows
df=pd.read_csv('pima-indians-diabetes.csv',skiprows=5)

# %%
df
# Out:
#       0  137  40  35  168  43.1  2.288  33  1
# 0     5  116  74   0    0  25.6  0.201  30  0
# 1     3   78  50  32   88  31.0  0.248  26  1
# 2    10  115   0   0    0  35.3  0.134  29  0
# 3     2  197  70  45  543  30.5  0.158  53  1
# 4     8  125  96   0    0   0.0  0.232  54  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 758  10  101  76  48  180  32.9  0.171  63  0
# 759   2  122  70  27    0  36.8  0.340  27  0
# 760   5  121  72  23  112  26.2  0.245  30  0
# 761   1  126  60   0    0  30.1  0.349  47  1
# 762   1   93  70  31    0  30.4  0.315  23  0
#
# [763 rows x 9 columns]

# %%
df.shape
# Out:
# (763, 9)

# %%
df.dtypes
# Out:
# 0          int64
# 137        int64
# 40         int64
# 35         int64
# 168        int64
# 43.1     float64
# 2.288    float64
# 33         int64
# 1          int64
# dtype: object

# %%
 #descriptive statistics
df.describe().T
# Out:
#        count        mean         std     min      25%      50%       75%  \
# 0      763.0    3.849279    3.370333   0.000   1.0000    3.000    6.0000
# 137    763.0  120.845347   31.930571   0.000  99.0000  117.000  140.0000
# 40     763.0   69.154653   19.388681   0.000  62.0000   72.000   80.0000
# 35     763.0   20.511140   15.966774   0.000   0.0000   23.000   32.0000
# 168    763.0   79.979030  115.467529   0.000   0.0000   32.000  127.5000
# 43.1   763.0   31.999476    7.889569   0.000  27.3000   32.000   36.6000
# 2.288  763.0    0.469588    0.325484   0.078   0.2435    0.371    0.6215
# 33     763.0   33.239843   11.774406  21.000  24.0000   29.000   41.0000
# 1      763.0    0.347313    0.476429   0.000   0.0000    0.000    1.0000
#
#           max
# 0       17.00
# 137    199.00
# 40     122.00
# 35      99.00
# 168    846.00
# 43.1    67.10
# 2.288    2.42
# 33      81.00
# 1        1.00

# %%
#300.Class distribution
df['class'].value_counts()
# Out:
# 0    500
# 1    268
# Name: class, dtype: int64

# %%
#300 skewness of the distribution
df.skew()
# Out:
# Preg     0.901674
# Plas     0.173754
# Pres    -1.843608
# skin     0.109372
# test     2.272251
# mass    -0.428982
# pedi     1.919911
# age      1.129597
# class    0.635017
# dtype: float64

# %%
# 303 missing values 
df['class'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Name: class, Length: 768, dtype: bool

# %%
df.isnull().sum()
# Out:
# Preg     0
# Plas     0
# Pres     0
# skin     0
# test     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %% [raw]
# #304 visualization
#   1.histogram
#   2.density plot
#   3.box plot

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(10,8))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#305 density plot
df.plot(kind='density',subplots=True,layout=(3,3),sharex=False,figsize=(15,10))
plt.show()

# %%
#306
df.plot(kind='box',subplots=True,layout=(3,3),sharex=False,sharey=False,figsize=(15,10))
plt.show()

# %%
#307 correlation matrix
# 1. correlation matric
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
df.corr()
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# Plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# Pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# Preg   0.544341  0.221898
# Plas   0.263514  0.466581
# Pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %%
#308 scatter plot
pd.plotting.scatter_matrix(df,figsize=(10,10))
plt.show()
